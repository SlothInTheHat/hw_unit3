// %% [markdown]
// # Hack 1

// %% [markdown]
// ![image.png](attachment:image.png)

// %%
int myAge = 15;
int otherAge = 45;

// %% [markdown]
// 1. true
// 2. true
// 3. true
// 4. false
// 5. false
// 6. true

// %% [markdown]
// # Hack 2
// find the mistake

// %%
String myName = Alisha;

myName != Anika;
myName == Alisha;
String myName = Alisha;
cannot find symbol
symbol:variable Alisha
// Out:
// |   String myName = Alisha;
// cannot find symbol
//   symbol:   variable Alisha

// %% [markdown]
// Comparing strings should String methods

// %% [markdown]
// # Homework?
//
// What is this question missing information??????

// %% [markdown]
// # Popcorn Hack

// %%
public static void main(String[] args) {
    int myAge = 1;
    System.out.println("Current age: " + myAge);
    
    if (myAge >= 16) {
        System.out.println("You can start learning to drive!");
    }

    System.out.println("On your next birthday, you will be " + (myAge + 1) + " years old!");
}

main(null);
// Out:
// Current age: 1
// On your next birthday, you will be 2 years old!

// %% [markdown]
// # Hack
//
// ![image.png](attachment:image.png)
//
// Based on this code, if you were younger than 16 what would it print out?
// Write your own if else statement
//
// Answer it would just print You are not old enough for a licesne yet.

// %%
int money  = 10;

if (money > 20){
    System.out.println("you can buy a dinosaur.");
}

else{
    System.out.println("you can't buy a dinosaur");
}
// Out:
// you can't buy a dinosaur

// %% [markdown]
// ![image.png](attachment:image.png)
//
// 1. If I was 19 what would it print out?
//
// It will print you can vote and get a liscence
//
// 2. If I was 13 what would it print out?
//
// It would not print anything
//
// 3. Create your if statement with one else if condition.

// %%
int money  = 10;

if (money > 20){
    System.out.println("you can buy a dinosaur.");
}

else if (money >= 10){
    System.out.println("you can buy a car");
}

else{

    System.out.println("You can't buy anything");
}
// Out:
// you can buy a car

// %% [markdown]
// # Popcorn Hack

// %%
age 20
anual income 1500
student status: yes
function checkMembershipEligibility() {
    // Get user input
    let age = parseInt(prompt("Enter your age:"));  // Age input
    let income = parseFloat(prompt("Enter your annual income:"));  // Annual income input
    let isStudent = prompt("Are you a student? (yes/no):").toLowerCase() === 'yes';  // Student status input

    // Initialize an empty array to hold results
    let results = [];

    // Check eligibility for different memberships

    // Basic Membership
    if (age >= 18 && income >= 20000) {
        results.push("You qualify for Basic Membership.");
    }

    // Premium Membership
    if (age >= 25 && income >= 50000) {
        results.push("You qualify for Premium Membership.");
    }

    // Student Discount
    if (isStudent) {
        results.push("You are eligible for a Student Discount.");
    }

    // Senior Discount
    if (age >= 65) {
        results.push("You qualify for a Senior Discount.");
    }

    // If no eligibility, provide a default message
    if (results.length === 0) {
        results.push("You do not qualify for any memberships or discounts.");
    }

    // Output all results
    results.forEach(result => console.log(result));
}

// Call the function to execute
checkMembershipEligibility();
// Out:
// |   age 20
// ';' expected
//
// |   anual income 1500
// ';' expected
//
// |   student status: yes
// ';' expected
//
// |   function checkMembershipEligibility() {
// ';' expected
//
// |   function checkMembershipEligibility() {
// ';' expected
//
// |       let isStudent = prompt("Are you a student? (yes/no):").toLowerCase() === 'yes';  // Student status input
// illegal start of expression
//
// |       let isStudent = prompt("Are you a student? (yes/no):").toLowerCase() === 'yes';  // Student status input
// unclosed character literal
//
// |       let isStudent = prompt("Are you a student? (yes/no):").toLowerCase() === 'yes';  // Student status input
// unclosed character literal
//
// |       let isStudent = prompt("Are you a student? (yes/no):").toLowerCase() === 'yes';  // Student status input
// not a statement
//
// |       let results = [];
// illegal start of expression
//
// |       if (results.length === 0) {
// illegal start of expression
//
// ...

// %% [markdown]
// # Answer: it will print out "You are eligible for a Student Discount."

// %% [markdown]
// # Popcorn Hack
//
//
// Write a program that checks if a person can get a discount based on their age and student status. You can define your own discount criteria! Use compound conditionals to determine the output.

// %%
public class Main {
    public static void main(String[] args) {
        int age = 30;
        boolean isStudent = true;

        if (age < 18 && isStudent){
            System.out.println("DISCOUNT");
        }

        else{
            System.out.println("No Discount");
        }

        // Your compound conditional logic here
    }
}

Main.main(null);
// Out:
// No Discount

// %% [markdown]
// # Popcorn Hack
//
// Challenge Questions
//
// What is !(x == 0) equivalent to?
//
// x != 0
//
// Apply De Morgan’s Law to find an equivalent expression.
//
// Negate the expression (x < -5 || x > 10).
//
// −5≤x≤10
//
// Use De Morgan’s Law to rewrite this expression in a different form.

// %% [markdown]
// # Popcorn Hack

// %%
class House {
    private String color;
    private int size;

    public House(String color, int size) {
        this.color = color;
        this.size = size;
    }

    // Override equals method to compare House objects by content
    @Override
    public boolean equals(Object obj) {
        if (this == obj) return true;  // Check if same object reference
        if (obj == null || getClass() != obj.getClass()) return false;  // Check if same class
        House house = (House) obj;
        return size == house.size && color.equals(house.color);  // Compare attributes
    }
}

public class Main {
    public static void main(String[] args) {
        House myHouse = new House("green", 150);
        House anikasHouse = new House("green", 150);
        House sharonsHouse = new House("green", 150);

        // Correct comparison using equals()
        System.out.println(myHouse.equals(sharonsHouse));  // This should return true
    }
}

// %% [markdown]
// Answer: Yes, the houses will be the same.

// %% [markdown]
// # Homework Hacks

// %%
import java.util.Scanner;

public class PrimeClubMembership {

    public static void main(String[] args) {
        Scanner scanner = new Scanner(System.in);

        System.out.print("Enter your age: ");
        int age = scanner.nextInt();

        System.out.print("Enter your annual income: ");
        double income = scanner.nextDouble();

        System.out.print("Are you a student? (yes/no): ");
        String studentStatus = scanner.next().toLowerCase();

        System.out.print("Enter your employment type (full-time, part-time, unemployed): ");
        String employmentType = scanner.next().toLowerCase();

        if (age < 0 || income < 0) {
            System.out.println("Age and income must be positive.");
            return;
        }

        if (!studentStatus.equals("yes") && !studentStatus.equals("no")) {
            System.out.println("Student status must be 'yes' or 'no'.");
            return;
        }

        if (!employmentType.equals("full-time") && !employmentType.equals("part-time") && !employmentType.equals("unemployed")) {
            System.out.println("Employment type must be 'full-time', 'part-time', or 'unemployed'.");
            return;
        }

        boolean qualifiesBasic = (age >= 18 && income >= 20000);
        boolean qualifiesPremium = (age >= 25 && income >= 50000);
        boolean qualifiesStudent = studentStatus.equals("yes");
        boolean qualifiesSenior = (age >= 65);

        boolean qualifiedForAny = false;

        if (qualifiesPremium) {
            System.out.println("You qualify for Premium Membership.");
            qualifiedForAny = true;
        } else if (qualifiesSenior) {
            System.out.println("You qualify for Senior Discount.");
            qualifiedForAny = true;
        } else if (qualifiesStudent) {
            System.out.println("You are eligible for a Student Discount.");
            qualifiedForAny = true;
        } else if (qualifiesBasic) {
            System.out.println("You qualify for Basic Membership.");
            qualifiedForAny = true;
        }

        if (!qualifiedForAny) {
            System.out.println("You do not qualify for any memberships or discounts.");
        } else {
            System.out.println("Based on your input, the best membership for you is: ");
            if (qualifiesPremium) {
                System.out.println("Premium Membership.");
            } else if (qualifiesSenior) {
                System.out.println("Senior Discount.");
            } else if (qualifiesStudent) {
                System.out.println("Student Discount.");
            } else if (qualifiesBasic) {
                System.out.println("Basic Membership.");
            }
        }

        scanner.close();
    }
}

PrimeClubMembership.main(null);
// Out:
// Enter your age: Enter your annual income: Are you a student? (yes/no): Enter your employment type (full-time, part-time, unemployed): You are eligible for a Student Discount.
// Based on your input, the best membership for you is:
// Student Discount.
